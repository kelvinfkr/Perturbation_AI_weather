# %%
# !pip install cartopy
#!pip install netcdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 44.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #First time compile we need to make folders

# %%
# !cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
mkdir perturbation_pangu

# %%
cd perturbation_pangu
# Out:
# /content/drive/MyDrive/perturbation_pangu

# %%
# !mkdir Irma_2017
# !mkdir Mangkhut_2018
# !mkdir Debbie_2017
# Out:
# mkdir: cannot create directory ‘Irma_2017’: File exists

# %%
ls
# Out:
# Irma_2017/  Ita_2014/  Shanzhu_2018/

# %% [markdown]
# #Prepare Data for Irma

# %%
cd /content/drive/MyDrive/perturbation_pangu/Irma_2017
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017

# %%
# !mkdir seven_day
# !mkdir three_day

# %%
cd /content/drive/MyDrive/perturbation_pangu/Irma_2017/seven_day
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017/seven_day

# %%
# !mkdir nc_input_data/

# %%
cd nc_input_data/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017/seven_day/nc_input_data

# %%
# Define your variables
year = '2017'  # e.g., '2020'
month = '09'   # e.g., '01' for January; ensure it's a two-digit format
date = '04'    # e.g., '15'; also ensure it's two-digit format

# Construct the command string using Python's f-string for formatting
command = f"gsutil -m cp -r " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/geopotential " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/specific_humidity " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/temperature " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/mean_sea_level_pressure " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/2m_temperature " \
          f"."

# Run the command
# !{command}

# %%
cd /content/drive/MyDrive/perturbation_pangu/Irma_2017/three_day/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017/three_day

# %%
# !mkdir nc_input_data/

# %%
cd nc_input_data/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017/three_day/nc_input_data

# %%
# Define your variables
year = '2017'  # e.g., '2020'
month = '09'   # e.g., '01' for January; ensure it's a two-digit format
date = '07'    # e.g., '15'; also ensure it's two-digit format

# Construct the command string using Python's f-string for formatting
command = f"gsutil -m cp -r " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/geopotential " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/specific_humidity " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/temperature " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/mean_sea_level_pressure " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/2m_temperature " \
          f"."

# Run the command
# !{command}

# %% [markdown]
# # Prepare data for Mangkhut

# %%
cd /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018

# %%
# !mkdir seven_day
# !mkdir three_day

# %%
cd /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/seven_day
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/seven_day

# %%
# !mkdir nc_input_data/

# %%
cd nc_input_data/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/seven_day/nc_input_data

# %%
# Define your variables
year = '2018'  # e.g., '2020'
month = '09'   # e.g., '01' for January; ensure it's a two-digit format
date = '09'    # e.g., '15'; also ensure it's two-digit format

# Construct the command string using Python's f-string for formatting
command = f"gsutil -m cp -r " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/geopotential " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/specific_humidity " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/temperature " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/mean_sea_level_pressure " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/2m_temperature " \
          f"."

# Run the command
# !{command}

# %%
cd /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/three_day
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/three_day

# %%
# !mkdir nc_input_data/

# %%
cd nc_input_data/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/three_day/nc_input_data

# %%
# Define your variables
year = '2018'  # e.g., '2020'
month = '09'   # e.g., '01' for January; ensure it's a two-digit format
date = '13'    # e.g., '15'; also ensure it's two-digit format

# Construct the command string using Python's f-string for formatting
command = f"gsutil -m cp -r " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/geopotential " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/specific_humidity " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/temperature " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/mean_sea_level_pressure " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/2m_temperature " \
          f"."

# Run the command
# !{command}

# %% [markdown]
# #Prepare data for Debbie

# %%
cd /content/drive/MyDrive/perturbation_pangu/Debbie_2017/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017

# %%
# !mkdir seven_day
# !mkdir three_day

# %%
cd /content/drive/MyDrive/perturbation_pangu/Debbie_2017/seven_day
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017/seven_day

# %%
# !mkdir nc_input_data/

# %%
cd nc_input_data/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017/seven_day/nc_input_data

# %%
# Define your variables
year = '2017'  # e.g., '2020'
month = '03'   # e.g., '01' for January; ensure it's a two-digit format
date = '21'    # e.g., '15'; also ensure it's two-digit format

# Construct the command string using Python's f-string for formatting
command = f"gsutil -m cp -r " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/geopotential " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/specific_humidity " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/temperature " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/mean_sea_level_pressure " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/2m_temperature " \
          f"."

# Run the command
# !{command}

# %%
cd /content/drive/MyDrive/perturbation_pangu/Debbie_2017/three_day
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017/three_day

# %%
# !mkdir nc_input_data/

# %%
cd nc_input_data/
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017/three_day/nc_input_data

# %%
# Define your variables
year = '2017'  # e.g., '2020'
month = '03'   # e.g., '01' for January; ensure it's a two-digit format
date = '25'    # e.g., '15'; also ensure it's two-digit format

# Construct the command string using Python's f-string for formatting
command = f"gsutil -m cp -r " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/geopotential " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/specific_humidity " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/temperature " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-pressure_level/{year}/{month}/{date}/v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/mean_sea_level_pressure " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind " \
          f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/2m_temperature " \
          f"."

# Run the command
# !{command}

# %% [markdown]
# # Prepare surface wind data for every day
#
# > Irma

# %%
cd /content/drive/MyDrive/perturbation_pangu/Irma_2017
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017

# %%
# !mkdir surface_wind_ERA5_data

# %%
cd /content/drive/MyDrive/perturbation_pangu/Irma_2017/surface_wind_ERA5_data
# Out:
# /content/drive/MyDrive/perturbation_pangu/Irma_2017/surface_wind_ERA5_data

# %%
from datetime import datetime, timedelta
import os

# Define your start date
start_year = 2017
start_month = 9
start_day = 3

# Create a datetime object for the start date
start_date = datetime(start_year, start_month, start_day)

# Loop over 7 days
for i in range(8):
    # Calculate the current date
    current_date = start_date + timedelta(days=i)

    # Format the year, month, and date in two-digit format
    year = current_date.strftime('%Y')
    month = current_date.strftime('%m')
    date = current_date.strftime('%d')

    # Create the folder for the current date if it doesn't exist
    folder_path = f"./{year}-{month}-{date}/"
    os.makedirs(folder_path, exist_ok=True)

    # Construct the command string using Python's f-string for formatting
    command = (f"gsutil -m cp -r "
               f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind "
               f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind "
               f"{folder_path}")

    # Execute the command using !{command} in Colab
    print(f"Downloading data for {year}-{month}-{date}...")
    # !{command}

# %%
import xarray as xr
import numpy as np
import os
from datetime import datetime, timedelta

# Function to read and extract the relevant slices from each file
def read_and_slice(file_path):
    with xr.open_dataset(file_path) as ds:
        return ds.variables['u10' if 'u_component' in file_path else 'v10'][0].values

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Irma_2017/surface_wind_ERA5_data'  # Modify this path according to where the data is stored


# Define your start date
start_date = datetime(2017, 9, 3)  # Modify this according to your start date

# Loop over 7 days
for i in range(8):
    # Calculate the current date
    current_date = start_date + timedelta(days=i)

    # Format the year, month, and date in the desired format
    date_str = current_date.strftime('%Y-%m-%d')

    # Define the file paths for u10 and v10
    u10_file_path = os.path.join(base_path, date_str, '10m_u_component_of_wind', 'surface.nc')
    v10_file_path = os.path.join(base_path, date_str, '10m_v_component_of_wind', 'surface.nc')

    # Read and slice the data for u10 and v10
    u10_data = read_and_slice(u10_file_path)
    v10_data = read_and_slice(v10_file_path)

    # Construct the filename for the numpy array
    npy_filename = os.path.join(base_path,date_str, f'surface_wind_{date_str}.npy')

    # Stack u10 and v10 into a single array and save it
    stacked_data = np.stack((u10_data, v10_data))
    np.save(npy_filename, stacked_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import os

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (-90, -40, 10, 40)  # Correct extent for the Caribbean region

# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Irma_2017/surface_wind_ERA5_data'

# Define the start and end dates
start_date = '2017-09-03'
end_date = '2017-09-10'

# Generate the list of dates between start and end dates
dates = [d.strftime('%Y-%m-%d') for d in pd.date_range(start_date, end_date)]

# Loop over the dates
for date in dates:
    # Construct the file path for the current date
    file_path = os.path.join(base_path, date, f'surface_wind_{date}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[0, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Create a figure and axis with a specific projection
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Create levels for the contour ranging from 0 to 80 m/s
    levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add a colorbar with defined boundaries of 0 to 80 m/s
    cbar = fig.colorbar(c, ax=ax, orientation='vertical', label='Wind Speed (m/s)', boundaries=[0, 80])

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the title and labels
    ax.set_title(f'Wind Speed Map - USA Region ({date})')
    ax.set_xlabel('Longitude')
    ax.set_ylabel('Latitude')
    ax.gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

    # Display the map or save it as a file
    plt.show()
    # plt.savefig(f'wind_speed_map_{date}.png')  # Uncomment this line to save the plot as a file

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os
import pandas as pd

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (110, 160, 5, 35)  # Correct extent for hong kong
# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Irma_2017/surface_wind_ERA5_data'

# Define the start and end dates
start_date = '2017-09-03'
end_date = '2017-09-10'

# Generate the list of dates between start and end dates
dates = [d.strftime('%Y-%m-%d') for d in pd.date_range(start_date, end_date)]

# Create a figure and subplots
fig, axes = plt.subplots(1, len(dates), figsize=(20, 4), subplot_kw={'projection': ccrs.PlateCarree()})

# Create levels for the contour ranging from 0 to 80 m/s
levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

# Loop over the dates and axes
for date, ax in zip(dates, axes):
    # Construct the file path for the current date
    file_path = os.path.join(base_path, date, f'surface_wind_{date}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[0, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the subplot title
    ax.set_title(date, fontsize=12)

# Remove the space between subplots
plt.subplots_adjust(wspace=0)

# Display the plot
plt.show()

# %% [markdown]
# # Mangkunt

# %%
cd /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018

# %%
# !mkdir surface_wind_ERA5_data

# %%
cd /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/surface_wind_ERA5_data
# Out:
# /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/surface_wind_ERA5_data

# %%
from datetime import datetime, timedelta
import os

# Define your start date
start_year = 2018
start_month = 9
start_day = 9

# Create a datetime object for the start date
start_date = datetime(start_year, start_month, start_day)

# Loop over 7 days
for i in range(8):
    # Calculate the current date
    current_date = start_date + timedelta(days=i)

    # Format the year, month, and date in two-digit format
    year = current_date.strftime('%Y')
    month = current_date.strftime('%m')
    date = current_date.strftime('%d')

    # Create the folder for the current date if it doesn't exist
    folder_path = f"./{year}-{month}-{date}/"
    os.makedirs(folder_path, exist_ok=True)

    # Construct the command string using Python's f-string for formatting
    command = (f"gsutil -m cp -r "
               f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind "
               f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind "
               f"{folder_path}")

    # Execute the command using !{command} in Colab
    print(f"Downloading data for {year}-{month}-{date}...")
    # !{command}
# Out:
# ...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2018/09/09/10m_u_component_of_wind/surface.nc...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2018/09/09/10m_v_component_of_wind/surface.nc...
# | [2/2 files][ 95.1 MiB/ 95.1 MiB] 100% Done
# Operation completed over 2 objects/95.1 MiB.
# ...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2018/09/10/10m_v_component_of_wind/surface.nc...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2018/09/10/10m_u_component_of_wind/surface.nc...
# | [2/2 files][ 95.1 MiB/ 95.1 MiB] 100% Done
# Operation completed over 2 objects/95.1 MiB.
# ...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2018/09/11/10m_u_component_of_wind/surface.nc...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2018/09/11/10m_v_component_of_wind/surface.nc...
# | [2/2 files][ 95.1 MiB/ 95.1 MiB] 100% Done
# ...

# %%
import xarray as xr
import numpy as np
import os
from datetime import datetime, timedelta

# Function to read and extract the relevant slices from each file
def read_and_slice(file_path):
    with xr.open_dataset(file_path) as ds:
        return ds.variables['u10' if 'u_component' in file_path else 'v10'][0].values

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/surface_wind_ERA5_data'  # Modify this path according to where the data is stored


# Define your start date
start_date = datetime(2018, 9, 9)  # Modify this according to your start date

# Loop over 7 days
for i in range(8):
    # Calculate the current date
    current_date = start_date + timedelta(days=i)

    # Format the year, month, and date in the desired format
    date_str = current_date.strftime('%Y-%m-%d')

    # Define the file paths for u10 and v10
    u10_file_path = os.path.join(base_path, date_str, '10m_u_component_of_wind', 'surface.nc')
    v10_file_path = os.path.join(base_path, date_str, '10m_v_component_of_wind', 'surface.nc')

    # Read and slice the data for u10 and v10
    u10_data = read_and_slice(u10_file_path)
    v10_data = read_and_slice(v10_file_path)

    # Construct the filename for the numpy array
    npy_filename = os.path.join(base_path,date_str, f'surface_wind_{date_str}.npy')

    # Stack u10 and v10 into a single array and save it
    stacked_data = np.stack((u10_data, v10_data))
    np.save(npy_filename, stacked_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os
import pandas as pd

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (110, 160, 5, 35)  # Correct extent for the Caribbean region

# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/surface_wind_ERA5_data'

# Define the start and end dates
start_date = '2018-09-09'
end_date = '2018-09-16'

# Generate the list of dates between start and end dates
dates = [d.strftime('%Y-%m-%d') for d in pd.date_range(start_date, end_date)]

# Create a figure and subplots
fig, axes = plt.subplots(1, len(dates), figsize=(20, 4), subplot_kw={'projection': ccrs.PlateCarree()})

# Create levels for the contour ranging from 0 to 80 m/s
levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

# Loop over the dates and axes
for date, ax in zip(dates, axes):
    # Construct the file path for the current date
    file_path = os.path.join(base_path, date, f'surface_wind_{date}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[0, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the subplot title
    ax.set_title(date, fontsize=12)

# Remove the space between subplots
plt.subplots_adjust(wspace=0)

# Display the plot
plt.show()

# %% [markdown]
# #Debbie

# %%
cd /content/drive/MyDrive/perturbation_pangu/Debbie_2017
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017

# %%
# !mkdir surface_wind_ERA5_data

# %%
cd /content/drive/MyDrive/perturbation_pangu/Debbie_2017/surface_wind_ERA5_data
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017/surface_wind_ERA5_data

# %%
from datetime import datetime, timedelta
import os

# Define your start date
start_year = 2017
start_month = 3
start_day = 21

# Create a datetime object for the start date
start_date = datetime(start_year, start_month, start_day)

# Loop over 7 days
for i in range(8):
    # Calculate the current date
    current_date = start_date + timedelta(days=i)

    # Format the year, month, and date in two-digit format
    year = current_date.strftime('%Y')
    month = current_date.strftime('%m')
    date = current_date.strftime('%d')

    # Create the folder for the current date if it doesn't exist
    folder_path = f"./{year}-{month}-{date}/"
    os.makedirs(folder_path, exist_ok=True)

    # Construct the command string using Python's f-string for formatting
    command = (f"gsutil -m cp -r "
               f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_u_component_of_wind "
               f"gs://gcp-public-data-arco-era5/raw/date-variable-single_level/{year}/{month}/{date}/10m_v_component_of_wind "
               f"{folder_path}")

    # Execute the command using !{command} in Colab
    print(f"Downloading data for {year}-{month}-{date}...")
    # !{command}
# Out:
# ...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2017/03/21/10m_u_component_of_wind/surface.nc...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2017/03/21/10m_v_component_of_wind/surface.nc...
# \ [2/2 files][ 95.1 MiB/ 95.1 MiB] 100% Done
# Operation completed over 2 objects/95.1 MiB.
# ...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2017/03/22/10m_u_component_of_wind/surface.nc...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2017/03/22/10m_v_component_of_wind/surface.nc...
# \ [2/2 files][ 95.1 MiB/ 95.1 MiB] 100% Done
# Operation completed over 2 objects/95.1 MiB.
# ...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2017/03/23/10m_u_component_of_wind/surface.nc...
# Copying gs://gcp-public-data-arco-era5/raw/date-variable-single_level/2017/03/23/10m_v_component_of_wind/surface.nc...
# | [2/2 files][ 95.1 MiB/ 95.1 MiB] 100% Done
# ...

# %%
import xarray as xr
import numpy as np
import os
from datetime import datetime, timedelta

# Function to read and extract the relevant slices from each file
def read_and_slice(file_path):
    with xr.open_dataset(file_path) as ds:
        return ds.variables['u10' if 'u_component' in file_path else 'v10'][0].values

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Debbie_2017/surface_wind_ERA5_data'  # Modify this path according to where the data is stored


# Define your start date
start_date = datetime(2017, 3, 21)  # Modify this according to your start date

# Loop over 7 days
for i in range(8):
    # Calculate the current date
    current_date = start_date + timedelta(days=i)

    # Format the year, month, and date in the desired format
    date_str = current_date.strftime('%Y-%m-%d')

    # Define the file paths for u10 and v10
    u10_file_path = os.path.join(base_path, date_str, '10m_u_component_of_wind', 'surface.nc')
    v10_file_path = os.path.join(base_path, date_str, '10m_v_component_of_wind', 'surface.nc')

    # Read and slice the data for u10 and v10
    u10_data = read_and_slice(u10_file_path)
    v10_data = read_and_slice(v10_file_path)

    # Construct the filename for the numpy array
    npy_filename = os.path.join(base_path,date_str, f'surface_wind_{date_str}.npy')

    # Stack u10 and v10 into a single array and save it
    stacked_data = np.stack((u10_data, v10_data))
    np.save(npy_filename, stacked_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import os
import pandas as pd

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (140, 160, -30, -10)  # Correct extent for the Caribbean region

# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Debbie_2017/surface_wind_ERA5_data'

# Define the start and end dates
start_date = '2017-03-21'
end_date = '2017-03-28'

# Generate the list of dates between start and end dates
dates = [d.strftime('%Y-%m-%d') for d in pd.date_range(start_date, end_date)]

# Create a figure and subplots
fig, axes = plt.subplots(1, len(dates), figsize=(20, 4), subplot_kw={'projection': ccrs.PlateCarree()})

# Create levels for the contour ranging from 0 to 80 m/s
levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

# Loop over the dates and axes
for date, ax in zip(dates, axes):
    # Construct the file path for the current date
    file_path = os.path.join(base_path, date, f'surface_wind_{date}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[0, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the subplot title
    ax.set_title(date, fontsize=12)

# Remove the space between subplots
plt.subplots_adjust(wspace=0)

# Display the plot
plt.show()

# %% [markdown]
# # Forecast_direct_Irma

# %%
cd /content/drive/MyDrive/perturbation_pangu/Irma_2017/seven_day/output_data_direct

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import os

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (-90, -40, 10, 40)  # Correct extent for the Caribbean region

# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Irma_2017/seven_day/output_data_direct'

# Define the start and end dates
start_date = '2017-09-04'
end_date = '2017-09-10'

# Generate the list of dates between start and end dates
steps = range(1,8)

fig, axes = plt.subplots(1, len(steps), figsize=(20, 4), subplot_kw={'projection': ccrs.PlateCarree()})

levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

# Loop over the dates
for step,ax in zip(steps, axes):
    # Construct the file path for the current date
    file_path = os.path.join(base_path, f'output_surface_step_{step}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[2, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the subplot title
    ax.set_title(step, fontsize=12)
    # Display the map or save it as a file
plt.subplots_adjust(wspace=0)

plt.show()
    # plt.savefig(f'wind_speed_map_{date}.png')  # Uncomment this line to save the plot as a file

# %% [markdown]
# #Forecast_direct_Mangkhut

# %%
cd /content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/seven_day/output_data_direct

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import os

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (110, 160, 5, 35)   # Correct extent for the Caribbean region

# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Mangkhut_2018/seven_day/output_data_direct'
# Generate the list of dates between start and end dates
steps = range(1,8)

fig, axes = plt.subplots(1, len(steps), figsize=(20, 4), subplot_kw={'projection': ccrs.PlateCarree()})

levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

# Loop over the dates
for step,ax in zip(steps, axes):
    # Construct the file path for the current date
    file_path = os.path.join(base_path, f'output_surface_step_{step}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[2, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the subplot title
    ax.set_title(step, fontsize=12)
    # Display the map or save it as a file
plt.subplots_adjust(wspace=0)

plt.show()
    # plt.savefig(f'wind_speed_map_{date}.png')  # Uncomment this line to save the plot as a file

# %% [markdown]
# #Forecast_Direct_Debbie

# %%
cd /content/drive/MyDrive/perturbation_pangu/Debbie_2017/seven_day/output_data_direct
# Out:
# /content/drive/MyDrive/perturbation_pangu/Debbie_2017/seven_day/output_data_direct

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import pandas as pd
import os

# Custom extent (min_lon, min_lat, max_lon, max_lat)
custom_extent = (140, 160, -30, -10)   # Correct extent for the Caribbean region

# Create a meshgrid of longitudes and latitudes
lon = np.linspace(0.125, 359.875, 1440)
lat = np.linspace(90, -90, 721)
lon_grid, lat_grid = np.meshgrid(lon, lat)

# Define the base path where the data is stored
base_path = '/content/drive/MyDrive/perturbation_pangu/Debbie_2017/seven_day/output_data_direct'
# Generate the list of dates between start and end dates
steps = range(1,8)

fig, axes = plt.subplots(1, len(steps), figsize=(20, 4), subplot_kw={'projection': ccrs.PlateCarree()})

levels = np.linspace(0, 40, num=10)  # This creates 10 levels from 0 to 40 inclusive

# Loop over the dates
for step,ax in zip(steps, axes):
    # Construct the file path for the current date
    file_path = os.path.join(base_path, f'output_surface_step_{step}.npy')

    # Load the data from the file
    temp = np.load(file_path)
    u10 = temp[2, :, :]
    v10 = temp[1, :, :]

    # Calculate wind speed from u10 and v10
    wind_speed = np.sqrt(u10**2 + v10**2)

    # Set the extent of the map to the custom region
    ax.set_extent(custom_extent, crs=ccrs.PlateCarree())

    # Plot the wind speed map with specified levels
    c = ax.contourf(lon_grid, lat_grid, wind_speed, levels=levels, cmap='viridis', extend='both', transform=ccrs.PlateCarree())

    # Add coastlines and borders
    ax.coastlines(resolution='110m', color='black', linewidth=0.8)
    ax.add_feature(cfeature.BORDERS, linestyle='-', edgecolor='black', linewidth=0.5)

    # Set the subplot title
    ax.set_title(step, fontsize=12)
    # Display the map or save it as a file
plt.subplots_adjust(wspace=0)

plt.show()
    # plt.savefig(f'wind_speed_map_{date}.png')  # Uncomment this line to save the plot as a file
